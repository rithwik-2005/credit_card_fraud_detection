# %%
import pandas as pd

# %%
df=pd.read_csv(r"d:/major_ml/credit_card_fraud_detection/data/credit_data.csv")

# %%
df.describe(include="all")
# Out:
#         TransactionID             TransactionDate         Amount  \
# count   100000.000000                      100000  100000.000000
# unique            NaN                      100000            NaN
# top               NaN  2024-05-20 18:56:36.027551            NaN
# freq              NaN                           1            NaN
# mean     50000.500000                         NaN    2497.092666
# std      28867.657797                         NaN    1442.415999
# min          1.000000                         NaN       1.050000
# 25%      25000.750000                         NaN    1247.955000
# 50%      50000.500000                         NaN    2496.500000
# 75%      75000.250000                         NaN    3743.592500
# max     100000.000000                         NaN    4999.770000
#
#            MerchantID TransactionType Location        IsFraud
# count   100000.000000          100000   100000  100000.000000
# ...

# %%
df.head(1)
# Out:
#    TransactionID             TransactionDate   Amount  MerchantID  \
# 0              1  2024-04-03 14:15:35.462794  4189.27         688
#
#   TransactionType     Location  IsFraud
# 0          refund  San Antonio        0

# %%
df.dtypes
# Out:
# TransactionID        int64
# TransactionDate     object
# Amount             float64
# MerchantID           int64
# TransactionType     object
# Location            object
# IsFraud              int64
# dtype: object
